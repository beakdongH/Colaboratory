# %% [markdown]
# <a href="https://colab.research.google.com/github/beakdongH/Colaboratory/blob/main/AImath09.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install matplotlib

# %%
import matplotlib.pyplot as plt

x_data =['MON','TUE','WED','THR','FIR','SAT','SUN']
y_data = [242,256,237,223,263,81,26]

plt.title("Weekly foot traffic data")
plt.xlabel("Days")
plt.ylabel("foot traffic")

plt.scatter(x_data[:5],y_data[:5],color='green')#점은 4번째 까지 출력
plt.plot(x_data,y_data)
plt.show()

# %%
import numpy as np #엑셀이 없어서 실행이 안된다..
import pandas as sp
import matplotlib.pyplot as plt


df = sp.read_csv("titanic.circ")
df["survived"] #생존한 행렬
df["survived"].sum()/len(df)

survive = df.groupby("who")["survived"].sum()
num = df.groupby("who")["survived"].count()

result =[]
for i in range(9):
  df_cls = result.append(df.query(f"age >= {i} and age < {i+9}"))
  psur = df_cls["survived"].sum()/df_cls["survived"].count()
  print(psur)

#전체

plt.plot(survive/sum)
plt.show()
